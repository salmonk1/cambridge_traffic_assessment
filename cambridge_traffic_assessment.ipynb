# %%
import os

import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
import seaborn as sns
from pprint import pprint
from sodapy import Socrata
# %matplotlib inline

import scipy.stats as stats
import math
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# get list of files based on csv or xlsx

# %%
path = os.getcwd()
file_names = os.listdir(path)
file_names
# Out:
# ['RTC Location 2018.csv',
#  '.DS_Store',
#  'raw_data',
#  'RTC Location 2016.xlsx',
#  'RTC Location 2017_0.xlsx',
#  'RTC Location 2015.xlsx',
#  'RTC Location 2014.xlsx',
#  '.ipynb_checkpoints',
#  'cam_traffic_eda.ipynb',
#  'RTC Location 2013.xlsx',
#  'RTC Location 2012.xlsx']

# %%
for x in file_names:
    files_xlsx = [f for f in file_names if f[-4:] == 'xlsx']
    files_csv = [f for f in file_names if f[-3:] == 'csv']

# %%
files_xlsx
# Out:
# ['RTC Location 2016.xlsx',
#  'RTC Location 2017_0.xlsx',
#  'RTC Location 2015.xlsx',
#  'RTC Location 2014.xlsx',
#  'RTC Location 2013.xlsx',
#  'RTC Location 2012.xlsx']

# %%
df = pd.DataFrame()

# %%
headers = []
for f in files_xlsx:
    data = pd.read_excel(f)
    headers.append(data.columns)

# %%
year2017 = pd.read_excel('/Users/ksalmon/Desktop/traffic/RTC Location 2017_0.xlsx')

# %%
year2016 = pd.read_excel('/Users/ksalmon/Desktop/traffic/RTC Location 2016.xlsx')

# %%
len(year2016.columns)
# Out:
# 54

# %%
len(year2017.columns)
# Out:
# 36

# %%
len(year2016.columns.difference(year2017.columns))
# Out:
# 46

# %%
files_csv
# Out:
# ['RTC Location 2018.csv']

# %%
files_xls
# Out:
# ['RTC Location 2016.xlsx',
#  'RTC Location 2017_0.xlsx',
#  'RTC Location 2015.xlsx',
#  'RTC Location 2014.xlsx',
#  'RTC Location 2013.xlsx',
#  'RTC Location 2012.xlsx',
#  'RTC Location 2018.csv']

# %%
year2016.head(20).T
# Out:
#                                                                        0   \
# Reference                                                            2016
# Date                                                             20160106
# Year                                                                 2016
# Month                                                                   1
# Day                                                                     6
# Day.1                                                           Wednesday
# Time                                                                  725
# Severity                                                           Slight
# Road_Class                                                              A
# Main_rd_no                                                             14
# Junction Detail                                                 Slip road
# Light                                                                Dark
# ...

# %%
year2018 = pd.read_csv('/Users/ksalmon/Desktop/traffic/RTC Location 2018.csv')

# %%
year2018.head(20).T
# Out:
#                                                     0   \
# Date                                          20180101
# Police_ref                                    18263388
# Easting                                         519784
# Northing                                        299454
# Severity                                    2. Serious
# Road_cond                                  2. Wet/Damp
# Visibility  4. Darkness: street lights present and lit
# Casualties                                           1
# Pedestrian                                           0
# Cycles                                               0
# P2W                                                  0
# OAPs                                                 0
# Children                                             0
# Manoeuvre                                   0. No turn
# Time                                             05:03
# Vehicles                                             2
# ...

# %%
df1 = pd.read_excel('/Users/ksalmon/Desktop/traffic/raw_data/RTC Location 2012.xlsx')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2319 entries, 0 to 2318
# Data columns (total 54 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Reference                 2319 non-null   int64
#  1   Date                      2319 non-null   int64
#  2   Year                      2319 non-null   int64
#  3   Month                     2319 non-null   int64
#  4   Day                       2319 non-null   int64
#  5   Day.1                     2319 non-null   object
#  6   Time                      2319 non-null   int64
#  7   Severity                  2319 non-null   object
#  8   Road_Class                2319 non-null   object
#  9   Main_rd_no                2319 non-null   int64
#  10  Junction Detail           2319 non-null   object
#  11  Light                     2319 non-null   object
#  12  Weather                   2319 non-null   object
#  13  Surface                   2319 non-null   object
# ...

# %%
df1.describe()
# Out:
#            Reference          Date    Year        Month          Day  \
# count    2319.000000  2.319000e+03  2319.0  2319.000000  2319.000000
# mean   317518.511427  2.012070e+07  2012.0     6.875377    15.782665
# std    176438.845667  3.451519e+02     0.0     3.453561     8.763021
# min       112.000000  2.012010e+07  2012.0     1.000000     1.000000
# 25%    167012.000000  2.012042e+07  2012.0     4.000000     8.000000
# 50%    326412.000000  2.012072e+07  2012.0     7.000000    16.000000
# 75%    472862.000000  2.012101e+07  2012.0    10.000000    23.000000
# max    904612.000000  2.012123e+07  2012.0    12.000000    31.000000
#
#               Time   Main_rd_no  Speed_limit  Unnamed: 25  Pedestrian_1_Age  \
# count  2319.000000  2319.000000  2319.000000  2319.000000       2319.000000
# mean   1356.081501   465.569642    43.691246     0.102199          3.079776
# std     489.316355   522.974118    16.037635     0.314160         11.608070
# ...

# %%
df1.Weather.value_counts()
# Out:
# Fine (no wind)     1661
# Rain (no wind)      271
# Unknown             235
# Uncoded              75
# Raining & windy      27
# Fine & windy         24
# Fog/mist             19
# Snow (no wind)        7
# Name: Weather, dtype: int64

# %%
df1[df1['Severity'] == 'Fatal']['Cycle']
# Out:
# 64      N
# 163     N
# 207     N
# 254     N
# 262     N
# 417     N
# 508     N
# 635     N
# 729     N
# 732     N
# 759     N
# 853     N
# 903     N
# 941     N
# 1126    N
# 1190    N
# 1211    N
# 1237    N
# 1478    N
# 1581    N
# 1632    N
# 1653    N
# 1721    N
# 1800    N
# 1941    N
# 1952    N
# 1979    N
# 2075    N
# 2236    N
# 2255    N
# Name: Cycle, dtype: object

# %%
df1[df1['Cycle'] == 'Y']
# Out:
#       Reference      Date  Year  Month  Day      Day.1  Time Severity  \
# 3          2912  20121221  2012     12   21     Friday    15  Serious
# 4          3112  20120103  2012      1    3    Tuesday  1745   Slight
# 8          4312  20120104  2012      1    4  Wednesday  1520   Slight
# 25        11412  20120109  2012      1    9     Monday  2000  Serious
# 41         7012  20120106  2012      1    6     Friday   935   Slight
# 55        12212  20120111  2012      1   11  Wednesday   840   Slight
# 62        14612  20120112  2012      1   12   Thursday   810   Slight
# 63        15412  20120112  2012      1   12   Thursday  1745   Slight
# 70        17112  20120113  2012      1   13     Friday  1310   Slight
# 76        19312  20120113  2012      1   13     Friday  1400   Slight
# 88        22912  20121221  2012     12   21     Friday   755   Slight
# 90        23412  20120117  2012      1   17    Tuesday   600   Slight
# ...
